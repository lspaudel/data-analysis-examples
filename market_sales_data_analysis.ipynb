# %% [markdown]
# ## About the data
#
# The Supermarket Sales Dataset provides a comprehensive overview of supermarket transactions, tracking details such as product categories, unit prices, quantities sold, and gross income. It also includes customer demographics, such as gender, payment method, and membership type. This dataset is ideal for analyzing sales trends, customer behavior, and revenue performance, offering insights to optimize promotions and product strategies.
#
# Key fields include:
#
# - Invoice ID: A unique identifier for each transaction.
# - Branch: The specific supermarket branch (e.g., A, B, C).
# - City: The city where the branch is located.
# - Customer Type: Indicates if the customer is a "Member" or "Normal."
# - Gender: Customer's gender for demographic insights.
# - Product Line: Product category (e.g., Groceries, Clothing).
# - Unit Price: Price per product unit.
# - Quantity: Units bought in a transaction.
# - Tax (5%): Tax amount (5% of the total before tax).
# - Total: Total paid, including tax.
# - Date/Time: Date and time of purchase, helpful for identifying peak hours.
# - Payment: Payment method (e.g., Cash, Credit Card).
# - COGS (Cost of Goods Sold): Production cost of the goods sold.
# - Gross Margin Percentage: Percentage difference between sales and COGS.
# - Gross Income: Income after deducting COGS.
# - Rating: Customer satisfaction rating (typically 1-5 scale).
# This dataset is a powerful tool for extracting insights into purchasing trends and customer preferences, aiding in the development of targeted strategies for revenue growth and customer satisfaction.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./supermarket_sales.csv')

# %%
data.shape #check number of rows and columns
# Out:
# (1000, 17)

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
data.columns # display the column names
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.dtypes #show the datat types for each column
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.info() # basic information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
data.isnull().sum() # check if there are any null nan or NaN values
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.notnull().sum() # non-null values
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
# Since the date is object , let's convert it into Datetime
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
# x = data['City'].map({'Mandalay':1, 'Naypyitaw':2, 'Yangon':3 })

# %%
data['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
# lets index the data using Date
data.set_index('Date', inplace =True)

# %%
data.head(5)
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity   Tax 5%     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415  548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155  340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880  489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085  634.3785
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# 2019-01-05  13:08      Ewallet  522.83                 4.761905       26.1415
# 2019-03-08  10:29         Cash   76.40                 4.761905        3.8200
# 2019-03-03  13:23  Credit card  324.31                 4.761905       16.2155
# 2019-01-27  20:33      Ewallet  465.76                 4.761905       23.2880
# 2019-02-08  10:37      Ewallet  604.17                 4.761905       30.2085
#
#             Rating
# Date
# 2019-01-05     9.1
# 2019-03-08     9.6
# 2019-03-03     7.4
# 2019-01-27     8.4
# 2019-02-08     5.3

# %%
data.describe()  # Statistical Summary
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
data.dropna(inplace=True) #drop any null values if it is present in the data

# %%
data
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
# ...                 ...    ...        ...           ...     ...
# 2019-01-29  233-67-5758      C  Naypyitaw        Normal    Male
# 2019-03-02  303-96-2227      B   Mandalay        Normal  Female
# 2019-02-09  727-02-1313      A     Yangon        Member    Male
# 2019-02-22  347-56-2442      A     Yangon        Normal    Male
# 2019-02-18  849-09-3807      A     Yangon        Member  Female
#
#                       Product line  Unit price  Quantity   Tax 5%      Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  26.1415   548.9715
# 2019-03-08  Electronic accessories       15.28         5   3.8200    80.2200
# 2019-03-03      Home and lifestyle       46.33         7  16.2155   340.5255
# 2019-01-27       Health and beauty       58.22         8  23.2880   489.0480
# 2019-02-08       Sports and travel       86.31         7  30.2085   634.3785
# ...                            ...         ...       ...      ...        ...
# 2019-01-29       Health and beauty       40.35         1   2.0175    42.3675
# 2019-03-02      Home and lifestyle       97.38        10  48.6900  1022.4900
# 2019-02-09      Food and beverages       31.84         1   1.5920    33.4320
# 2019-02-22      Home and lifestyle       65.82         1   3.2910    69.1110
# 2019-02-18     Fashion accessories       88.34         7  30.9190   649.2990
#
#              Time      Payment    cogs  gross margin percentage  gross income  \
# Date
# 2019-01-05  13:08      Ewallet  522.83                 4.761905       26.1415
# 2019-03-08  10:29         Cash   76.40                 4.761905        3.8200
# 2019-03-03  13:23  Credit card  324.31                 4.761905       16.2155
# 2019-01-27  20:33      Ewallet  465.76                 4.761905       23.2880
# 2019-02-08  10:37      Ewallet  604.17                 4.761905       30.2085
# ...           ...          ...     ...                      ...           ...
# 2019-01-29  13:46      Ewallet   40.35                 4.761905        2.0175
# 2019-03-02  17:16      Ewallet  973.80                 4.761905       48.6900
# 2019-02-09  13:22         Cash   31.84                 4.761905        1.5920
# 2019-02-22  15:33         Cash   65.82                 4.761905        3.2910
# 2019-02-18  13:28         Cash  618.38                 4.761905       30.9190
#
#             Rating
# Date
# 2019-01-05     9.1
# 2019-03-08     9.6
# 2019-03-03     7.4
# 2019-01-27     8.4
# 2019-02-08     5.3
# ...            ...
# 2019-01-29     6.2
# 2019-03-02     4.4
# 2019-02-09     7.7
# 2019-02-22     4.1
# 2019-02-18     6.6
#
# [1000 rows x 16 columns]

# %%
numeric_data = data.select_dtypes(include=np.number)

# %%
numeric_data.columns
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
numeric_data.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# Tax 5%                                       NaN      1.000000 -0.036442
# Total                                        NaN      1.000000 -0.036442
# cogs                                         NaN      1.000000 -0.036442
# gross margin percentage                      NaN           NaN       NaN
# gross income                                 NaN      1.000000 -0.036442
# Rating                                       NaN     -0.036442  1.000000

# %%
# Plot correlation heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plotting Histogram for all
numeric_data.hist(figsize=(12,12))
plt.show()

# %%
# find the mean Rating
plt.figure(dpi=125)
sns.histplot(data = data['Rating'],bins=6, binrange=(4,10)) # can also use displot() function
plt.axvline(x=data['Rating'].mean(), c='blue', label='Mean Rating')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (5,5))
data['Branch'].value_counts().plot(kind = 'pie', autopct = '%0.2f%%')
plt.title('Branch Distribution')
plt.show()

# %%
plt.figure(figsize = (5,5))
data['City'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
plt.ylabel('')
plt.title('City Distribution')
plt.show()

# %%
data.groupby('City')['Total'].mean().sort_values()
# Out:
# City
# Yangon       312.354031
# Mandalay     319.872506
# Naypyitaw    337.099715
# Name: Total, dtype: float64

# %%
data.groupby('Quantity').max()
# Out:
#            Invoice ID Branch    City Customer type Gender       Product line  \
# Quantity
# 1         896-34-0956      C  Yangon        Normal   Male  Sports and travel
# 2         883-69-1285      C  Yangon        Normal   Male  Sports and travel
# 3         895-66-0685      C  Yangon        Normal   Male  Sports and travel
# 4         889-04-9723      C  Yangon        Normal   Male  Sports and travel
# 5         892-05-6689      C  Yangon        Normal   Male  Sports and travel
# 6         891-01-7034      C  Yangon        Normal   Male  Sports and travel
# 7         891-58-8335      C  Yangon        Normal   Male  Sports and travel
# 8         894-41-5205      C  Yangon        Normal   Male  Sports and travel
# 9         898-04-2717      C  Yangon        Normal   Male  Sports and travel
# 10        884-80-6021      C  Yangon        Normal   Male  Sports and travel
#
#           Unit price   Tax 5%      Total   Time  Payment    cogs  \
# Quantity
# 1              99.69   4.9845   104.6745  20:47  Ewallet   99.69
# 2              99.89   9.9890   209.7690  20:46  Ewallet  199.78
# 3              99.70  14.9550   314.0550  20:59  Ewallet  299.10
# 4              99.42  19.8840   417.5640  20:50  Ewallet  397.68
# 5              99.78  24.9450   523.8450  20:59  Ewallet  498.90
# 6              99.92  29.9760   629.4960  20:54  Ewallet  599.52
# 7              99.96  34.9860   734.7060  20:52  Ewallet  699.72
# 8              99.56  39.8240   836.3040  20:54  Ewallet  796.48
# 9              99.96  44.9820   944.6220  20:51  Ewallet  899.64
# 10             99.30  49.6500  1042.6500  20:55  Ewallet  993.00
#
#           gross margin percentage  gross income  Rating
# Quantity
# 1                        4.761905        4.9845     9.9
# 2                        4.761905        9.9890     9.8
# 3                        4.761905       14.9550    10.0
# 4                        4.761905       19.8840     9.8
# 5                        4.761905       24.9450     9.9
# 6                        4.761905       29.9760    10.0
# 7                        4.761905       34.9860     9.9
# 8                        4.761905       39.8240     9.9
# 9                        4.761905       44.9820    10.0
# 10                       4.761905       49.6500    10.0
